# %% [markdown]
# # PUBLICATION
# ## Long-Range Redox and Water Activation at Metal-Water Interfaces with Ferroelectric Ordering
#
# Arthur Hagopian <sup>1</sup>, Jean-Sébastien Filhol <sup>2</sup>, Tobias Binninger <sup>3</sup>
# <sup>1</sup> Leiden Institute of Chemistry, Leiden University, Leiden 2333CC, the Netherlands
# <sup>2</sup> ICGM, CNRS, University of Montpellier, Montpellier, France
# <sup>3</sup> Theory and Computation of Energy Materials (IET-3), Institute of Energy Technologies, Forschungszentrum Jülich GmbH, 52425 Jülich, Germany
#
# [GitHub Repository](https://github.com/yourusername/your-repo-name)
#
# ---
#
# This notebook analyzes Density Functional Theory (DFT) results for free-standing and Au(111)-supported ferroelectric ice slabs.
# Key data (e.g., DOS, Bader charges) are extracted from VASP output files and visualized.

# %%
# Standard libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import re
import plotly.graph_objects as go

# Personal library - Contains all the functions for this notebook
try:
    import myfunctions as mf
except ImportError:
    print("Could not import 'myfunctions.py'. Make sure it exists in the same folder as this notebook.")

# Configure logger
mf.configure_logger()

# %%
# General path to the data
data_directory = "./"

# List available systems
systems = sorted([
    item for item in os.listdir(data_directory)
    if os.path.isdir(os.path.join(data_directory, item))
    and item.startswith("ice")
])

print("Available systems:", systems)
# Out:
# Available systems: ['ice_free_standing', 'ice_supported_Au_111']

# %%
# Upload data
data = mf.load_all_data()

print("  📊 Data overview:\n")
for key, subdict in data.items():
    subdict_type = type(subdict).__name__
    size = len(subdict)
    
    # Default preview values
    subkey_preview = "empty"
    value_preview = "n/a"
    
    try:
        first_key = next(iter(subdict))
        subkey_preview = repr(first_key)

        first_value = subdict[first_key]
        value_type = type(first_value).__name__
        
        # Try to get shape/length info
        try:
            shape = first_value.shape
        except AttributeError:
            try:
                shape = f"len={len(first_value)}"
            except TypeError:
                shape = "scalar"

        value_preview = f"{value_type}, {shape}"
    except StopIteration:
        pass  # empty subdict

    print(f"  - {key:<12} | type: {subdict_type:<10} | len: {size:<3} | first key: {subkey_preview:<10} | first val: {value_preview}")
# Out:
#   📊 Data overview:
#
#   - H_positions  | type: dict       | len: 24  | first key: PosixPath('ice_free_standing/00_frozen/bilayer_2/CONTCAR') | first val: ndarray, (96, 3)
#   - O_positions  | type: dict       | len: 24  | first key: PosixPath('ice_free_standing/00_frozen/bilayer_2/CONTCAR') | first val: ndarray, (48, 3)
#   - Au_positions | type: dict       | len: 24  | first key: PosixPath('ice_free_standing/00_frozen/bilayer_2/CONTCAR') | first val: NoneType, scalar
#   - pdos         | type: dict       | len: 25  | first key: PosixPath('single_water_molecule/DOSCAR') | first val: dict, len=2
#   - bader        | type: dict       | len: 12  | first key: PosixPath('ice_free_standing/00_frozen/bilayer_2/ACF.dat') | first val: list, len=144

# %% [markdown]
# ## 1. Free-standing ice slabs

# %% [markdown]
# ### PDOS

# %% [markdown]
# #### Frozen systems

# %%
mf.plot_pdos_all_bilayers(
    data,
    base_path="ice_free_standing/00_frozen",
    folder_label="bilayer",
    z_bounds = [0.00, 0.24, 0.32, 0.40, 0.48, 0.56, 1.00],
    max_layers=6
)
# Out:
# --- bilayer_1 ---
# --- bilayer_2 ---
# --- bilayer_3 ---
# --- bilayer_4 ---
# --- bilayer_5 ---
# --- bilayer_6 ---

# %% [markdown]
# #### Relaxed systems

# %%
mf.plot_pdos_all_bilayers(
    data,
    base_path="ice_free_standing/01_relaxed",
    folder_label="bilayer",
    z_bounds = [0.00, 0.24, 0.32, 0.40, 0.48, 0.56, 1.00],
    max_layers=6
)
# Out:
# --- bilayer_1 ---
# --- bilayer_2 ---
# --- bilayer_3 ---
# --- bilayer_4 ---
# --- bilayer_5 ---
# --- bilayer_6 ---

# %% [markdown]
# ### Bader charge

# %% [markdown]
# #### Frozen systems

# %%
mf.plot_bilayer_avg_charge(
    data,
    base_path="ice_free_standing/00_frozen",
    z_bounds = [0.00, 0.24, 0.32, 0.40, 0.48, 0.56, 1.00],
    max_layers=6
)

# %% [markdown]
# #### Relaxed systems

# %%
mf.plot_bilayer_avg_charge(
    data,
    base_path="ice_free_standing/01_relaxed",
    z_bounds = [0.00, 0.24, 0.32, 0.40, 0.48, 0.56, 1.00],
    max_layers=6
)

# %% [markdown]
# ## 2. Au(111)-supported ice slabs

# %% [markdown]
# ### PDOS

# %% [markdown]
# #### Frozen systems - Hdown

# %%
mf.plot_pdos_all_bilayers(
    data,
    base_path="ice_supported_Au_111/00_frozen",
    folder_label="Hdown",
    z_bounds=[0.00, 0.24, 0.32, 0.40, 0.48, 0.56, 1.00],
    max_layers=6
)
# Out:
# --- bilayer_1 ---
# --- bilayer_2 ---
# --- bilayer_3 ---
# --- bilayer_4 ---
# --- bilayer_5 ---
# --- bilayer_6 ---

# %% [markdown]
# #### Frozen systems - Hup

# %%
mf.plot_pdos_all_bilayers(
    data,
    base_path="ice_supported_Au_111/00_frozen",
    folder_label="Hup",
    z_bounds=[0.00, 0.26, 0.34, 0.42, 0.50, 0.58, 1.00],
    max_layers=6
)
# Out:
# --- bilayer_1 ---
# --- bilayer_2 ---
# --- bilayer_3 ---
# --- bilayer_4 ---
# --- bilayer_5 ---
# --- bilayer_6 ---

# %%
path = list(data['H_positions'].keys())[4]
print(path)
H = data['H_positions'][path]
O = data['O_positions'][path]

cell = np.array([
    [14.6976995467999991, 0, 0],
    [-7.3488497733999996, 12.7285811846999994, 0],
    [0, 0, 49.2004013061999999]
])

mf.plotly_3d_atoms(H,O,cell=cell)
